# %% [markdown]
# <a href="https://colab.research.google.com/github/khuloodnasher/Visualizing-Part-of-Speech/blob/main/Visualizing_POS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
# loading the spaacy English Language
nlp=spacy.load('en_core_web_sm')
# Create my text as nlp object
doc1=nlp(u"With most COVID-19 vaccines, you will need two shots in order for them to work.")

# %%
from spacy import displacy
# Render the dependency parse :
displacy.render(doc1, style='dep',jupyter=True)# showing syntactic dependency and POS tags
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a1c2a939742041ae94d5477605f13451-0" class="displacy" width="2675" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">With</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
# ...

# %%
doc1=nlp(u"With most COVID-19 vaccines, you will need two shots in order for them to work.")
displacy.render(doc1, style='dep',jupyter=True,options={'distance':80})# showing syntactic dependency and POS tags
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0d91563d04af43028ead0a25a483e42d-0" class="displacy" width="1250" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">With</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
# ...

# %% [markdown]
# # Explaining Dependency

# %%
for token in doc1:
    print(f'{token.text:{10}} {token.pos_:{7}} {token.dep_:{7}} {spacy.explain(token.dep_)}')
# Out:
# With       ADP     prep    prepositional modifier
# most       ADJ     amod    adjectival modifier
# COVID-19   ADJ     amod    adjectival modifier
# vaccines   NOUN    pobj    object of preposition
# ,          PUNCT   punct   punctuation
# you        PRON    nsubj   nominal subject
# will       VERB    aux     auxiliary
# need       VERB    ROOT    None
# two        NUM     nummod  numeric modifier
# shots      NOUN    dobj    direct object
# in         ADP     prep    prepositional modifier
# order      NOUN    pobj    object of preposition
# for        ADP     mark    marker
# them       PRON    nsubj   nominal subject
# to         PART    aux     auxiliary
# work       VERB    advcl   adverbial clause modifier
# .          PUNCT   punct   punctuation

# %% [markdown]
# ## Visualization Options

# %%
doc1=nlp(u"With most COVID-19 vaccines, you will need two shots in order for them to work.")
options={'distance':90,'compact':'True','color':'black','bg':'#F9E79F','font':'Times'}
displacy.render(doc1, style='dep',jupyter=True,options=options)# showing options
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="11cd7870be264ef8a908a5bbbbed2f5c-0" class="displacy" width="1400" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: black; background: #F9E79F; font-family: Times; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">With</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
# ...
